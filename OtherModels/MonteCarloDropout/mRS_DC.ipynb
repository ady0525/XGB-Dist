# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams.update(plt.rcParamsDefault)
import os, sys

from scipy.stats import norm, skewnorm
from scipy.stats import gaussian_kde
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.utils import resample
from sklearn.metrics import accuracy_score, classification_report, make_scorer, log_loss, roc_auc_score, brier_score_loss
from sklearn.metrics import mean_squared_error, mean_absolute_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
proj_dir = 'C:/Users/ady05/Desktop/NU/DANA/NVQI/prob_learning_new/'
workspace = proj_dir + 'OtherModels/MC-mrs/'
util_dir = proj_dir + 'OtherModels/utils/'
data_dir = proj_dir + 'datasets/'
proc_dir = proj_dir + 'data processing/'

# %%
sys.path.insert(0, util_dir)
from data_proc import data_proc_mrs6
from plot_measures import (
    plot_confusion_matrix,
    plot_roc,
    plot_outcome_prob_relation,
    plot_feature_importance
)

# %% [markdown]
# # Data processing

# %%
df_comb = pd.read_excel(proc_dir + 'comb.xlsx')
df_num = pd.read_excel(data_dir + 'vargroups_numeric_new.xlsx')
df_cat = pd.read_excel(data_dir + 'vargroups_categorical_new.xlsx')

groupname = 'group postop'

# %%
X_data, y_data, num_names, cat_names = data_proc_mrs6(df_comb, df_num, df_cat, groupname)

(X_data.shape, y_data.shape)
# Out:
# ((3588, 97), (3588,))

# %%
if hasattr(y_data, "toarray"):  # Check if y_data is a sparse matrix
    y_data = y_data.toarray().ravel() 
X_train, X_test, y_train, y_test = train_test_split(
    X_data, y_data, stratify=y_data, test_size=0.2, random_state=1121218
)

(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# ((2870, 97), (2870,), (718, 97), (718,))

# %% [markdown]
# # MC dropout model

# %%
tf.random.set_seed(42)

def build_mc_dropout_model(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        Dense(1)  
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae']) 
    return model

input_shape = X_train.shape[1]
mc_dropout_model = build_mc_dropout_model(input_shape)
mc_dropout_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

n_samples = 100  
y_preds_mc = []

for _ in range(n_samples):
    y_pred = mc_dropout_model(X_test, training=True)  
    y_preds_mc.append(y_pred)

y_preds_mc = np.array(y_preds_mc)
y_mean_mc = y_preds_mc.mean(axis=0).ravel()  
y_std_mc = y_preds_mc.std(axis=0).ravel() 

mse_mc = mean_squared_error(y_test, y_mean_mc)
mae_mc = mean_absolute_error(y_test, y_mean_mc)

print(f"Monte Carlo Dropout Mean Squared Error (MSE): {mse_mc:.4f}")
print(f"Monte Carlo Dropout Mean Absolute Error (MAE): {mae_mc:.4f}")
# Out:
# Epoch 1/20
# C:\Users\ady05\anaconda3\envs\xgb_dist2\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 8.0966 - mae: 2.2205 - val_loss: 3.0003 - val_mae: 1.3837
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.2345 - mae: 1.6071 - val_loss: 2.9096 - val_mae: 1.3540
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.5505 - mae: 1.4992 - val_loss: 2.5219 - val_mae: 1.2571
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5133 - mae: 1.4475 - val_loss: 2.4728 - val_mae: 1.2457
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3485 - mae: 1.4377 - val_loss: 2.4625 - val_mae: 1.2395
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.1517 - mae: 1.3889 - val_loss: 2.4713 - val_mae: 1.2290
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8573 - mae: 1.3337 - val_loss: 2.3500 - val_mae: 1.1993
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9031 - mae: 1.3301 - val_loss: 2.2603 - val_mae: 1.1727
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8149 - mae: 1.3090 - val_loss: 2.3951 - val_mae: 1.2167
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6723 - mae: 1.2896 - val_loss: 2.2971 - val_mae: 1.1843
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6110 - mae: 1.2680 - val_loss: 2.2813 - val_mae: 1.1818
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7033 - mae: 1.2968 - val_loss: 2.2206 - val_mae: 1.1635
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4559 - mae: 1.2311 - val_loss: 2.0514 - val_mae: 1.1100
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4624 - mae: 1.2299 - val_loss: 2.0936 - val_mae: 1.1185
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.4640 - mae: 1.2390 - val_loss: 2.0839 - val_mae: 1.1251
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3431 - mae: 1.1972 - val_loss: 2.0445 - val_mae: 1.1114
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.3324 - mae: 1.2106 - val_loss: 2.0697 - val_mae: 1.1155
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2851 - mae: 1.1989 - val_loss: 2.0797 - val_mae: 1.1258
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2027 - mae: 1.1711 - val_loss: 2.0396 - val_mae: 1.1095
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1518 - mae: 1.1499 - val_loss: 2.1013 - val_mae: 1.1263
# Monte Carlo Dropout Mean Squared Error (MSE): 2.2911
# Monte Carlo Dropout Mean Absolute Error (MAE): 1.1972

# %% [markdown]
# # Measures

# %%
def root_mean_squared_error(y_pred, y_test):
    return np.sqrt(mean_squared_error(y_pred, y_test))
def normal_nll(loc, scale, y_test):
    return -norm.logpdf(y_test.flatten(), loc=loc, scale=scale).mean()
